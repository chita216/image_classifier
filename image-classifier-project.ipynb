# %% [markdown]
# ## Prepare the workspace

# %%
# Before you proceed, update the PATH
# Restart the Kernel at this point. 
# import os
# os.environ['PATH'] = f"{os.environ['PATH']}:/root/.local/bin"
# os.environ['PATH'] = f"{os.environ['PATH']}:/opt/conda/lib/python3.6/site-packages"

# %%
# Do not execute the commands below unless you have restart the Kernel after updating the PATH. 
# !python -m pip install torch==1.0.0

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Should return True when GPU is enabled.
# Out:
# 2.0.0
# True

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='../input/aipnd-project/flower_data/train/1/image_06734.jpg' width="500px">
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import pandas as pd
import numpy as np
import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import json
import os
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz).

# %% [markdown]
# If you do not find the `flowers/` dataset in the current directory, **/workspace/home/aipnd-project/**, you can download it using the following commands.
#
# ```bash
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers
# ```

# %%
imagenet_data = datasets.ImageFolder('../input/flower_data')
data_loader = torch.utils.data.DataLoader(imagenet_data,
                                          batch_size=32,
                                          shuffle=True,
                                          num_workers=0)

# %% [markdown]
# ## Data Description
# The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = '../input/flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# TODO: Define your transforms for the training, validation, and testing sets
train_transform = transforms.Compose([transforms.RandomRotation(15),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])
valid_transform = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

test_transform = transforms.Compose([transforms.Resize(255),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],
                                                          [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transform)
valid_data = datasets.ImageFolder(valid_dir, transform=valid_transform)
test_data = datasets.ImageFolder(test_dir, transform=test_transform)

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(train_data, 
                                           batch_size=32, 
                                           shuffle=True,
                                           num_workers=os.cpu_count() if str(device) == "cuda" else 0,
                                           pin_memory=True if str(device) == "cuda" else False)
valid_loader = torch.utils.data.DataLoader(valid_data, 
                                           batch_size=32,
                                           shuffle=True,
                                           num_workers=os.cpu_count() if str(device) == "cuda" else 0,
                                           pin_memory=True if str(device) == "cuda" else False)
test_loader = torch.utils.data.DataLoader(test_data, 
                                          batch_size=32,
                                          shuffle=True,
                                          num_workers=os.cpu_count() if str(device) == "cuda" else 0,
                                          pin_memory=True if str(device) == "cuda" else False)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('../input/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# ## Note for Workspace users:
# If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
model = models.vgg16(pretrained=True)
model
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:09<00:00, 57.2MB/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Freeze parameters 
for param in model.parameters():
    param.requires_grad = False


model.classifier = nn.Sequential(nn.Linear(25088, 256),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(256, 102),
                                 nn.LogSoftmax(dim=1))

# %%
criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.classifier.parameters(), lr=0.002)

model.to(device);

# %%
epochs = 5
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
    for inputs, labels in train_loader:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if steps % print_every == 0:
            valid_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in valid_loader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)

                    valid_loss += batch_loss.item()
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Validate loss: {valid_loss/len(valid_loader):.3f}.. "
                  f"Validate accuracy: {accuracy/len(valid_loader):.3f}")
            running_loss = 0
            model.train()
# Out:
# Epoch 1/5.. Train loss: 5.992.. Validate loss: 5.282.. Validate accuracy: 0.082
# Epoch 1/5.. Train loss: 4.540.. Validate loss: 4.295.. Validate accuracy: 0.138
# Epoch 1/5.. Train loss: 4.434.. Validate loss: 4.067.. Validate accuracy: 0.153
# Epoch 1/5.. Train loss: 4.066.. Validate loss: 3.890.. Validate accuracy: 0.149
# Epoch 1/5.. Train loss: 4.055.. Validate loss: 3.593.. Validate accuracy: 0.218
# Epoch 1/5.. Train loss: 4.068.. Validate loss: 3.462.. Validate accuracy: 0.234
# Epoch 1/5.. Train loss: 3.694.. Validate loss: 3.288.. Validate accuracy: 0.278
# Epoch 1/5.. Train loss: 3.464.. Validate loss: 3.225.. Validate accuracy: 0.276
# Epoch 1/5.. Train loss: 3.418.. Validate loss: 3.116.. Validate accuracy: 0.310
# Epoch 1/5.. Train loss: 3.562.. Validate loss: 2.932.. Validate accuracy: 0.334
# Epoch 1/5.. Train loss: 3.339.. Validate loss: 2.779.. Validate accuracy: 0.370
# Epoch 1/5.. Train loss: 3.464.. Validate loss: 2.499.. Validate accuracy: 0.421
# Epoch 1/5.. Train loss: 2.995.. Validate loss: 2.489.. Validate accuracy: 0.408
# Epoch 1/5.. Train loss: 3.167.. Validate loss: 2.227.. Validate accuracy: 0.458
# Epoch 1/5.. Train loss: 2.916.. Validate loss: 2.245.. Validate accuracy: 0.468
# Epoch 1/5.. Train loss: 2.833.. Validate loss: 2.201.. Validate accuracy: 0.469
# Epoch 1/5.. Train loss: 2.782.. Validate loss: 2.172.. Validate accuracy: 0.458
# Epoch 1/5.. Train loss: 3.010.. Validate loss: 2.164.. Validate accuracy: 0.444
# Epoch 1/5.. Train loss: 2.759.. Validate loss: 2.100.. Validate accuracy: 0.483
# Epoch 1/5.. Train loss: 2.758.. Validate loss: 2.087.. Validate accuracy: 0.490
# Epoch 1/5.. Train loss: 2.639.. Validate loss: 1.917.. Validate accuracy: 0.515
# Epoch 1/5.. Train loss: 2.566.. Validate loss: 1.809.. Validate accuracy: 0.557
# Epoch 1/5.. Train loss: 2.677.. Validate loss: 1.776.. Validate accuracy: 0.564
# Epoch 1/5.. Train loss: 2.735.. Validate loss: 1.756.. Validate accuracy: 0.577
# Epoch 1/5.. Train loss: 2.579.. Validate loss: 1.714.. Validate accuracy: 0.549
# Epoch 1/5.. Train loss: 2.589.. Validate loss: 1.660.. Validate accuracy: 0.580
# Epoch 1/5.. Train loss: 2.553.. Validate loss: 1.706.. Validate accuracy: 0.565
# Epoch 1/5.. Train loss: 2.520.. Validate loss: 1.545.. Validate accuracy: 0.611
# Epoch 1/5.. Train loss: 2.191.. Validate loss: 1.474.. Validate accuracy: 0.615
# Epoch 1/5.. Train loss: 2.399.. Validate loss: 1.511.. Validate accuracy: 0.615
# Epoch 1/5.. Train loss: 2.211.. Validate loss: 1.493.. Validate accuracy: 0.618
# Epoch 1/5.. Train loss: 2.419.. Validate loss: 1.351.. Validate accuracy: 0.657
# Epoch 1/5.. Train loss: 2.419.. Validate loss: 1.288.. Validate accuracy: 0.658
# Epoch 1/5.. Train loss: 2.323.. Validate loss: 1.338.. Validate accuracy: 0.640
# Epoch 1/5.. Train loss: 2.195.. Validate loss: 1.322.. Validate accuracy: 0.636
# Epoch 1/5.. Train loss: 2.367.. Validate loss: 1.346.. Validate accuracy: 0.636
# Epoch 1/5.. Train loss: 2.333.. Validate loss: 1.431.. Validate accuracy: 0.627
# Epoch 1/5.. Train loss: 2.242.. Validate loss: 1.348.. Validate accuracy: 0.642
# Epoch 1/5.. Train loss: 2.192.. Validate loss: 1.326.. Validate accuracy: 0.641
# Epoch 1/5.. Train loss: 2.200.. Validate loss: 1.335.. Validate accuracy: 0.625
# Epoch 1/5.. Train loss: 2.080.. Validate loss: 1.264.. Validate accuracy: 0.650
# Epoch 2/5.. Train loss: 1.884.. Validate loss: 1.237.. Validate accuracy: 0.676
# Epoch 2/5.. Train loss: 1.783.. Validate loss: 1.286.. Validate accuracy: 0.646
# Epoch 2/5.. Train loss: 2.236.. Validate loss: 1.234.. Validate accuracy: 0.667
# Epoch 2/5.. Train loss: 2.036.. Validate loss: 1.248.. Validate accuracy: 0.667
# Epoch 2/5.. Train loss: 1.665.. Validate loss: 1.182.. Validate accuracy: 0.685
# Epoch 2/5.. Train loss: 1.851.. Validate loss: 1.100.. Validate accuracy: 0.700
# Epoch 2/5.. Train loss: 1.890.. Validate loss: 1.040.. Validate accuracy: 0.713
# Epoch 2/5.. Train loss: 1.683.. Validate loss: 1.027.. Validate accuracy: 0.715
# Epoch 2/5.. Train loss: 1.846.. Validate loss: 1.091.. Validate accuracy: 0.706
# Epoch 2/5.. Train loss: 1.779.. Validate loss: 1.068.. Validate accuracy: 0.703
# Epoch 2/5.. Train loss: 1.850.. Validate loss: 1.099.. Validate accuracy: 0.719
# Epoch 2/5.. Train loss: 2.183.. Validate loss: 1.102.. Validate accuracy: 0.706
# Epoch 2/5.. Train loss: 1.999.. Validate loss: 1.075.. Validate accuracy: 0.713
# Epoch 2/5.. Train loss: 2.005.. Validate loss: 1.130.. Validate accuracy: 0.701
# Epoch 2/5.. Train loss: 1.985.. Validate loss: 1.229.. Validate accuracy: 0.681
# Epoch 2/5.. Train loss: 1.752.. Validate loss: 1.185.. Validate accuracy: 0.694
# Epoch 2/5.. Train loss: 1.890.. Validate loss: 1.137.. Validate accuracy: 0.709
# Epoch 2/5.. Train loss: 1.702.. Validate loss: 1.115.. Validate accuracy: 0.704
# Epoch 2/5.. Train loss: 1.901.. Validate loss: 1.132.. Validate accuracy: 0.703
# Epoch 2/5.. Train loss: 1.807.. Validate loss: 1.106.. Validate accuracy: 0.696
# Epoch 2/5.. Train loss: 1.901.. Validate loss: 1.098.. Validate accuracy: 0.688
# Epoch 2/5.. Train loss: 1.971.. Validate loss: 1.054.. Validate accuracy: 0.704
# Epoch 2/5.. Train loss: 1.800.. Validate loss: 1.112.. Validate accuracy: 0.700
# Epoch 2/5.. Train loss: 1.667.. Validate loss: 1.083.. Validate accuracy: 0.718
# Epoch 2/5.. Train loss: 2.213.. Validate loss: 1.039.. Validate accuracy: 0.723
# Epoch 2/5.. Train loss: 2.126.. Validate loss: 1.083.. Validate accuracy: 0.708
# Epoch 2/5.. Train loss: 1.735.. Validate loss: 1.071.. Validate accuracy: 0.701
# Epoch 2/5.. Train loss: 1.893.. Validate loss: 1.125.. Validate accuracy: 0.683
# Epoch 2/5.. Train loss: 1.817.. Validate loss: 1.140.. Validate accuracy: 0.711
# Epoch 2/5.. Train loss: 1.917.. Validate loss: 1.156.. Validate accuracy: 0.702
# Epoch 2/5.. Train loss: 1.717.. Validate loss: 1.073.. Validate accuracy: 0.711
# Epoch 2/5.. Train loss: 1.930.. Validate loss: 0.977.. Validate accuracy: 0.740
# Epoch 2/5.. Train loss: 1.991.. Validate loss: 1.036.. Validate accuracy: 0.714
# Epoch 2/5.. Train loss: 1.851.. Validate loss: 1.087.. Validate accuracy: 0.710
# Epoch 2/5.. Train loss: 1.815.. Validate loss: 1.125.. Validate accuracy: 0.712
# Epoch 2/5.. Train loss: 1.679.. Validate loss: 1.158.. Validate accuracy: 0.691
# Epoch 2/5.. Train loss: 2.122.. Validate loss: 1.099.. Validate accuracy: 0.701
# Epoch 2/5.. Train loss: 1.811.. Validate loss: 0.988.. Validate accuracy: 0.735
# Epoch 2/5.. Train loss: 1.867.. Validate loss: 0.971.. Validate accuracy: 0.741
# Epoch 2/5.. Train loss: 2.007.. Validate loss: 0.990.. Validate accuracy: 0.731
# Epoch 2/5.. Train loss: 1.613.. Validate loss: 0.978.. Validate accuracy: 0.738
# Epoch 3/5.. Train loss: 1.621.. Validate loss: 0.983.. Validate accuracy: 0.738
# Epoch 3/5.. Train loss: 1.530.. Validate loss: 0.981.. Validate accuracy: 0.742
# Epoch 3/5.. Train loss: 1.787.. Validate loss: 1.001.. Validate accuracy: 0.736
# Epoch 3/5.. Train loss: 1.881.. Validate loss: 0.997.. Validate accuracy: 0.743
# Epoch 3/5.. Train loss: 1.579.. Validate loss: 0.987.. Validate accuracy: 0.746
# Epoch 3/5.. Train loss: 1.531.. Validate loss: 0.980.. Validate accuracy: 0.750
# Epoch 3/5.. Train loss: 1.614.. Validate loss: 0.952.. Validate accuracy: 0.749
# Epoch 3/5.. Train loss: 1.840.. Validate loss: 0.947.. Validate accuracy: 0.732
# Epoch 3/5.. Train loss: 1.765.. Validate loss: 1.058.. Validate accuracy: 0.705
# Epoch 3/5.. Train loss: 1.617.. Validate loss: 1.175.. Validate accuracy: 0.692
# Epoch 3/5.. Train loss: 2.046.. Validate loss: 1.235.. Validate accuracy: 0.690
# Epoch 3/5.. Train loss: 1.513.. Validate loss: 1.177.. Validate accuracy: 0.685
# Epoch 3/5.. Train loss: 1.792.. Validate loss: 1.049.. Validate accuracy: 0.718
# Epoch 3/5.. Train loss: 1.292.. Validate loss: 0.976.. Validate accuracy: 0.729
# Epoch 3/5.. Train loss: 1.846.. Validate loss: 0.949.. Validate accuracy: 0.728
# Epoch 3/5.. Train loss: 1.694.. Validate loss: 0.950.. Validate accuracy: 0.726
# Epoch 3/5.. Train loss: 1.676.. Validate loss: 0.956.. Validate accuracy: 0.734
# Epoch 3/5.. Train loss: 1.557.. Validate loss: 0.981.. Validate accuracy: 0.733
# Epoch 3/5.. Train loss: 1.667.. Validate loss: 0.938.. Validate accuracy: 0.764
# Epoch 3/5.. Train loss: 1.636.. Validate loss: 0.986.. Validate accuracy: 0.758
# Epoch 3/5.. Train loss: 1.934.. Validate loss: 0.975.. Validate accuracy: 0.746
# Epoch 3/5.. Train loss: 1.892.. Validate loss: 0.940.. Validate accuracy: 0.760
# Epoch 3/5.. Train loss: 1.798.. Validate loss: 0.933.. Validate accuracy: 0.749
# Epoch 3/5.. Train loss: 1.515.. Validate loss: 0.975.. Validate accuracy: 0.748
# Epoch 3/5.. Train loss: 1.810.. Validate loss: 0.977.. Validate accuracy: 0.741
# Epoch 3/5.. Train loss: 1.762.. Validate loss: 0.974.. Validate accuracy: 0.733
# Epoch 3/5.. Train loss: 1.793.. Validate loss: 0.901.. Validate accuracy: 0.748
# Epoch 3/5.. Train loss: 1.539.. Validate loss: 0.908.. Validate accuracy: 0.756
# Epoch 3/5.. Train loss: 1.632.. Validate loss: 0.948.. Validate accuracy: 0.734
# Epoch 3/5.. Train loss: 1.657.. Validate loss: 0.901.. Validate accuracy: 0.750
# Epoch 3/5.. Train loss: 1.627.. Validate loss: 0.873.. Validate accuracy: 0.759
# Epoch 3/5.. Train loss: 1.948.. Validate loss: 0.871.. Validate accuracy: 0.766
# Epoch 3/5.. Train loss: 1.610.. Validate loss: 0.853.. Validate accuracy: 0.782
# Epoch 3/5.. Train loss: 1.398.. Validate loss: 0.931.. Validate accuracy: 0.749
# Epoch 3/5.. Train loss: 1.702.. Validate loss: 0.882.. Validate accuracy: 0.751
# Epoch 3/5.. Train loss: 1.533.. Validate loss: 0.930.. Validate accuracy: 0.750
# Epoch 3/5.. Train loss: 1.561.. Validate loss: 0.950.. Validate accuracy: 0.743
# Epoch 3/5.. Train loss: 1.961.. Validate loss: 0.917.. Validate accuracy: 0.741
# Epoch 3/5.. Train loss: 1.783.. Validate loss: 0.944.. Validate accuracy: 0.750
# Epoch 3/5.. Train loss: 1.714.. Validate loss: 0.986.. Validate accuracy: 0.744
# Epoch 3/5.. Train loss: 1.708.. Validate loss: 0.971.. Validate accuracy: 0.745
# Epoch 4/5.. Train loss: 1.854.. Validate loss: 0.921.. Validate accuracy: 0.757
# Epoch 4/5.. Train loss: 1.643.. Validate loss: 0.901.. Validate accuracy: 0.755
# Epoch 4/5.. Train loss: 1.867.. Validate loss: 0.946.. Validate accuracy: 0.752
# Epoch 4/5.. Train loss: 1.575.. Validate loss: 0.906.. Validate accuracy: 0.763
# Epoch 4/5.. Train loss: 1.612.. Validate loss: 0.919.. Validate accuracy: 0.769
# Epoch 4/5.. Train loss: 1.526.. Validate loss: 0.950.. Validate accuracy: 0.767
# Epoch 4/5.. Train loss: 1.642.. Validate loss: 1.059.. Validate accuracy: 0.739
# Epoch 4/5.. Train loss: 1.583.. Validate loss: 1.038.. Validate accuracy: 0.741
# Epoch 4/5.. Train loss: 1.506.. Validate loss: 1.036.. Validate accuracy: 0.730
# Epoch 4/5.. Train loss: 1.443.. Validate loss: 1.070.. Validate accuracy: 0.720
# Epoch 4/5.. Train loss: 1.631.. Validate loss: 1.021.. Validate accuracy: 0.741
# Epoch 4/5.. Train loss: 1.588.. Validate loss: 0.980.. Validate accuracy: 0.749
# Epoch 4/5.. Train loss: 1.335.. Validate loss: 1.018.. Validate accuracy: 0.744
# Epoch 4/5.. Train loss: 1.707.. Validate loss: 1.047.. Validate accuracy: 0.737
# Epoch 4/5.. Train loss: 1.545.. Validate loss: 1.000.. Validate accuracy: 0.755
# Epoch 4/5.. Train loss: 1.694.. Validate loss: 0.955.. Validate accuracy: 0.745
# Epoch 4/5.. Train loss: 1.478.. Validate loss: 0.932.. Validate accuracy: 0.757
# Epoch 4/5.. Train loss: 1.553.. Validate loss: 0.924.. Validate accuracy: 0.742
# Epoch 4/5.. Train loss: 1.954.. Validate loss: 0.966.. Validate accuracy: 0.738
# Epoch 4/5.. Train loss: 1.259.. Validate loss: 0.962.. Validate accuracy: 0.744
# Epoch 4/5.. Train loss: 1.466.. Validate loss: 0.990.. Validate accuracy: 0.727
# Epoch 4/5.. Train loss: 1.644.. Validate loss: 0.986.. Validate accuracy: 0.741
# Epoch 4/5.. Train loss: 1.899.. Validate loss: 0.983.. Validate accuracy: 0.743
# Epoch 4/5.. Train loss: 1.467.. Validate loss: 0.948.. Validate accuracy: 0.760
# Epoch 4/5.. Train loss: 1.702.. Validate loss: 0.889.. Validate accuracy: 0.767
# Epoch 4/5.. Train loss: 1.717.. Validate loss: 0.844.. Validate accuracy: 0.786
# Epoch 4/5.. Train loss: 1.691.. Validate loss: 0.854.. Validate accuracy: 0.776
# Epoch 4/5.. Train loss: 1.558.. Validate loss: 0.912.. Validate accuracy: 0.761
# Epoch 4/5.. Train loss: 1.694.. Validate loss: 0.940.. Validate accuracy: 0.748
# Epoch 4/5.. Train loss: 1.428.. Validate loss: 0.908.. Validate accuracy: 0.771
# Epoch 4/5.. Train loss: 1.871.. Validate loss: 0.926.. Validate accuracy: 0.768
# Epoch 4/5.. Train loss: 1.370.. Validate loss: 0.883.. Validate accuracy: 0.767
# Epoch 4/5.. Train loss: 1.661.. Validate loss: 0.882.. Validate accuracy: 0.772
# Epoch 4/5.. Train loss: 1.399.. Validate loss: 0.886.. Validate accuracy: 0.767
# Epoch 4/5.. Train loss: 1.770.. Validate loss: 0.879.. Validate accuracy: 0.778
# Epoch 4/5.. Train loss: 1.518.. Validate loss: 0.891.. Validate accuracy: 0.754
# Epoch 4/5.. Train loss: 1.577.. Validate loss: 0.839.. Validate accuracy: 0.775
# Epoch 4/5.. Train loss: 1.426.. Validate loss: 0.807.. Validate accuracy: 0.789
# Epoch 4/5.. Train loss: 1.364.. Validate loss: 0.806.. Validate accuracy: 0.771
# Epoch 4/5.. Train loss: 1.560.. Validate loss: 0.820.. Validate accuracy: 0.790
# Epoch 4/5.. Train loss: 1.402.. Validate loss: 0.794.. Validate accuracy: 0.797
# Epoch 5/5.. Train loss: 1.520.. Validate loss: 0.852.. Validate accuracy: 0.785
# Epoch 5/5.. Train loss: 1.165.. Validate loss: 0.884.. Validate accuracy: 0.774
# Epoch 5/5.. Train loss: 1.691.. Validate loss: 0.904.. Validate accuracy: 0.766
# Epoch 5/5.. Train loss: 1.596.. Validate loss: 0.785.. Validate accuracy: 0.793
# Epoch 5/5.. Train loss: 1.554.. Validate loss: 0.790.. Validate accuracy: 0.781
# Epoch 5/5.. Train loss: 1.294.. Validate loss: 0.830.. Validate accuracy: 0.773
# Epoch 5/5.. Train loss: 1.665.. Validate loss: 0.915.. Validate accuracy: 0.749
# Epoch 5/5.. Train loss: 1.334.. Validate loss: 0.891.. Validate accuracy: 0.767
# Epoch 5/5.. Train loss: 1.759.. Validate loss: 0.888.. Validate accuracy: 0.770
# Epoch 5/5.. Train loss: 1.725.. Validate loss: 0.933.. Validate accuracy: 0.779
# Epoch 5/5.. Train loss: 1.492.. Validate loss: 1.041.. Validate accuracy: 0.748
# Epoch 5/5.. Train loss: 1.765.. Validate loss: 0.977.. Validate accuracy: 0.759
# Epoch 5/5.. Train loss: 1.695.. Validate loss: 0.971.. Validate accuracy: 0.749
# Epoch 5/5.. Train loss: 1.802.. Validate loss: 0.968.. Validate accuracy: 0.768
# Epoch 5/5.. Train loss: 1.684.. Validate loss: 0.954.. Validate accuracy: 0.747
# Epoch 5/5.. Train loss: 1.642.. Validate loss: 0.929.. Validate accuracy: 0.756
# Epoch 5/5.. Train loss: 1.858.. Validate loss: 0.899.. Validate accuracy: 0.767
# Epoch 5/5.. Train loss: 1.358.. Validate loss: 0.914.. Validate accuracy: 0.758
# Epoch 5/5.. Train loss: 1.460.. Validate loss: 0.957.. Validate accuracy: 0.753
# Epoch 5/5.. Train loss: 1.753.. Validate loss: 0.918.. Validate accuracy: 0.759
# Epoch 5/5.. Train loss: 1.774.. Validate loss: 0.852.. Validate accuracy: 0.764
# Epoch 5/5.. Train loss: 1.868.. Validate loss: 0.855.. Validate accuracy: 0.763
# Epoch 5/5.. Train loss: 1.590.. Validate loss: 0.875.. Validate accuracy: 0.767
# Epoch 5/5.. Train loss: 1.357.. Validate loss: 0.980.. Validate accuracy: 0.754
# Epoch 5/5.. Train loss: 1.846.. Validate loss: 0.954.. Validate accuracy: 0.765
# Epoch 5/5.. Train loss: 1.541.. Validate loss: 0.969.. Validate accuracy: 0.733
# Epoch 5/5.. Train loss: 1.659.. Validate loss: 0.904.. Validate accuracy: 0.769
# Epoch 5/5.. Train loss: 1.668.. Validate loss: 0.886.. Validate accuracy: 0.768
# Epoch 5/5.. Train loss: 1.341.. Validate loss: 0.902.. Validate accuracy: 0.769
# Epoch 5/5.. Train loss: 1.600.. Validate loss: 0.874.. Validate accuracy: 0.776
# Epoch 5/5.. Train loss: 1.669.. Validate loss: 0.875.. Validate accuracy: 0.762
# Epoch 5/5.. Train loss: 1.258.. Validate loss: 0.897.. Validate accuracy: 0.764
# Epoch 5/5.. Train loss: 1.450.. Validate loss: 0.909.. Validate accuracy: 0.763
# Epoch 5/5.. Train loss: 1.609.. Validate loss: 0.898.. Validate accuracy: 0.783
# Epoch 5/5.. Train loss: 1.716.. Validate loss: 0.924.. Validate accuracy: 0.781
# Epoch 5/5.. Train loss: 1.732.. Validate loss: 0.880.. Validate accuracy: 0.774
# Epoch 5/5.. Train loss: 1.561.. Validate loss: 0.915.. Validate accuracy: 0.764
# Epoch 5/5.. Train loss: 1.251.. Validate loss: 0.874.. Validate accuracy: 0.783
# Epoch 5/5.. Train loss: 1.733.. Validate loss: 0.873.. Validate accuracy: 0.788
# Epoch 5/5.. Train loss: 1.618.. Validate loss: 0.934.. Validate accuracy: 0.767
# Epoch 5/5.. Train loss: 1.567.. Validate loss: 0.901.. Validate accuracy: 0.770

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
test_loss = 0
accuracy = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)

        test_loss += batch_loss.item()
        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test loss: {test_loss/len(test_loader):.3f}.. "
      f"Test accuracy: {accuracy/len(test_loader):.3f}")
# Out:
# Test loss: 0.996.. Test accuracy: 0.743

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
checkpoint = {'input_size': 25088,
              'output_size': 102,
              'model_state_dict': model.state_dict(),
              'optimizer_state_dict': optimizer.state_dict(),
              'classifier': model.classifier,
              'epochs': 5,
              'cat_to_name': cat_to_name}
torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = models.vgg16(pretrained=False)
    model.classifier = checkpoint['classifier']
    model.load_state_dict(checkpoint['model_state_dict'])
    model.cat_to_name = checkpoint['cat_to_name']
    return model

# %%
model = load_checkpoint('checkpoint.pth')
print(model)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=102, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
    (width, height) = (image.width, image.height)
    (width, height) = (256, 256*height // width)
    im_resized = image.resize((width, height))
    cropped_img = im_resized.crop((16, 16, 240, 240))
    np_image = np.array(cropped_img)/255
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_image = (np_image - mean)/std
    return np_image.transpose((2,0,1))

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
with Image.open("../input/flower_data/test/1/image_06743.jpg") as im:
    imshow(process_image(im))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval() 
    with Image.open(image_path) as im:
        image = process_image(im)
        image = torch.from_numpy(image).type(torch.FloatTensor)
        image = image.unsqueeze(0)
        image = image.to(device)
        
        with torch.no_grad():
            output = model.forward(image)

        # Calculate accuracy
        ps = torch.exp(output)
        top_p, top_class = ps.topk(topk)
        mapping = {key: val for key, val in model.cat_to_name.items()}
        classes = [mapping[str(item+1)] for item in top_class.to('cpu').numpy().tolist()[0]]
        top_p = top_p.to('cpu').numpy().flatten()
    return top_p, classes

# %%
predict("../input/flower_data/test/1/image_06764.jpg",model,10)
# Out:
# (array([0.5260101 , 0.12852389, 0.07440932, 0.04630305, 0.04566829,
#         0.03443627, 0.02853403, 0.02438016, 0.02011971, 0.01583742],
#        dtype=float32),
#  ['passion flower',
#   'mexican petunia',
#   'columbine',
#   'spear thistle',
#   'corn poppy',
#   'morning glory',
#   'sword lily',
#   'daffodil',
#   'trumpet creeper',
#   'cape flower'])

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
image_path = '../input/flower_data/test/60/image_02932.jpg'
top_p, classes = predict(image_path,model,5)
print(classes)
print(top_p)
fig, (ax1, ax2) = plt.subplots(2, 1)
with Image.open(image_path) as im:
    ax1=imshow(process_image(im),ax=ax1,title=str(classes[0]))

y_values = range(len(top_p))

# Plot the bar chart
ax2.barh(y_values, top_p, color='blue')
plt.yticks(y_values, classes)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ['pink-yellow dahlia', 'siam tulip', 'gaura', 'artichoke', 'buttercup']
# [9.7048402e-01 1.8874085e-02 9.2943199e-03 1.1241640e-03 6.1743725e-05]

# %% [markdown]
# ## Reminder for Workspace users
# If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
